# %%
# %matplotlib inline
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import numpy as np
import cv2
import glob
import time
from random import randint

from sklearn.svm import LinearSVC, SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from skimage.feature import hog

from sklearn.model_selection import GridSearchCV
from scipy.ndimage.measurements import label
from sklearn.utils import shuffle

# %%
test_img_files = glob.glob('../CarND-Vehicle-Detection/test_images/*.jpg')
img_test = mpimg.imread(test_img_files[3])

# %%
newtestimgdir = './data-augment/nonvehicles/'
test_img_files
# Out:
# ['../CarND-Vehicle-Detection/test_images/test1.jpg',
#  '../CarND-Vehicle-Detection/test_images/test2.jpg',
#  '../CarND-Vehicle-Detection/test_images/test3.jpg',
#  '../CarND-Vehicle-Detection/test_images/test4.jpg',
#  '../CarND-Vehicle-Detection/test_images/test5.jpg',
#  '../CarND-Vehicle-Detection/test_images/test6.jpg']

# %%
plt.imshow(img_test)

# %%
img = cv2.polylines(img_test, pts, isClosed=False, color=(255,0,0), )

# %%
pts = np.array([[600, 400], [0,500], [779, 1200]], np.int32)
pts = pts.reshape((-1,1,2))

# %%
pts
# Out:
# array([[[ 600,  400]],
#
#        [[   0,  500]],
#
#        [[ 779, 1200]]], dtype=int32)

# %%
plt.imshow(img)

# %%
pts = np.array([[10,5],[20,30],[70,20],[50,10]], np.int32)
pts = pts.reshape((-1,1,2))
img = cv2.polylines(img,[pts],True,(0,255,255))

# %%
plt.imshow(img)

# %%
randint(0, 800)
# Out:
# 503

# %%
for j in range(6): 
    img = mpimg.imread(test_img_files[j])
    for i in range(500):

        x = randint(0, 750)
        y = randint(400, 719 - 64)
        
        
        #img = cv2.rectangle(img, (x, y), (x + 64, y +64), (255, 0, 0), 3)
        cv2.imwrite(newtestimgdir + 'img_{}_{}.png'.format(j + 1, i), img[y:y+64,x:x+64])

# %%
plt.imshow(img)

# %%
import os

# %%
os.makedirs("./data-augment/nonvehicles")

# %%
plt.imshow(img[y:y+64, x:x+64])

# %%
len(range(6))
# Out:
# 6

# %%
for j in range(6): 
    img = mpimg.imread(test_img_files[j])
    for i in range(500):

        x = randint(0, 750)
        y = randint(400, 719 - 64)
        
        
        #img = cv2.rectangle(img, (x, y), (x + 64, y +64), (255, 0, 0), 3)
        cv2.imwrite(newtestimgdir + 'img_{}_{}.png'.format(j + 1, i), img[y:y+64,x:x+64])
